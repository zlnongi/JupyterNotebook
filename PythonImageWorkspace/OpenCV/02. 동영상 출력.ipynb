# %% [markdown]
# ## 2. 동영상 출력

# %% [markdown]
# ## 동영상 파일 출력

# %%
import cv2
cap = cv2.VideoCapture('video.mp4')

while cap.isOpened(): # 동영상 파일이 올바로 열렸는지?
    ret, frame = cap.read() # 성공 여부, frame : 받아온 이미지 (프레임)
    if not ret:
        print('더 이상 가져올 프레임이 없어요')
        break
    
    cv2.imshow('video', frame)
    
    if cv2.waitKey(1) == ord('q'): # q값 눌러서 종료
        print('사용자 입력에 의해 종료합니다.')
        break
cap.release() # 자원 해제
cv2.destroyAllWindows() # 모든 창 닫기
# Out:
# 더 이상 가져올 프레임이 없어요

# %% [markdown]
# ## 카메라 출력

# %%
import cv2
cap = cv2.VideoCapture(0) # 0번째 카메라 장치 (Device ID)

if not cap.isOpened(): # 카메라가 잘 열리지 않은 경우
    exit() # 프로그램 종료

while True: # 무한 반복
    ret, frame = cap.read()
    if not ret:
        break
        
    cv2.imshow('camera', frame)
    if cv2.waitKey(1) == ord('q'): # 사용자가 q를 입력하면
        break
        
cap.release()
cv2.destroyAllWindows()
# Out:
# 1   HIToolbox                           0x00007ff813cbf726 _ZN15MenuBarInstance22EnsureAutoShowObserverEv + 102
# 2   HIToolbox                           0x00007ff813cbf2b8 _ZN15MenuBarInstance14EnableAutoShowEv + 52
# 3   HIToolbox                           0x00007ff813c2ecd7 _ZN15MenuBarInstance21UpdateAggregateUIModeE21MenuBarAnimationStylehhh + 1113
# 4   HIToolbox                           0x00007ff813cbf173 _ZN15MenuBarInstance19SetFullScreenUIModeEjj + 175
# 5   AppKit                              0x00007ff80d182287 -[NSApplication _setPresentationOptions:instance:flags:] + 1145
# 6   AppKit                              0x00007ff80cfd7055 -[NSApplication _updateFullScreenPresentationOptionsForInstance:] + 582
# 7   CoreFoundation                      0x00007ff809db16c6 __CFNOTIFICATIONCENTER_IS_CALLING_OUT_TO_AN_OBSERVER__ + 137
# 8   CoreFoundation                      0x00007ff809e4acac ___CFXRegistrationPost_block_invoke + 86
# 9   CoreFoundation                      0x00007ff809e4ac03 _CFXRegistrationPost + 534
# 10  CoreFoundation                      0x00007ff809d84e21 _CFXNotificationPost + 809
# 11  Foundation                          0x00007ff80aafbabc -[NSNotificationCenter postNotificationName:object:userInfo:] + 82
# 12  AppKit                              0x00007ff80d1828f8 spacesNotificationHandler + 119
# 13  SkyLight                            0x00007ff80e92323d _ZN12_GLOBAL__N_123notify_datagram_handlerEj15CGSDatagramTypePvmS1_ + 1030
# 14  SkyLight                            0x00007ff80e9217f3 CGSSnarfAndDispatchDatagrams + 1055
# 15  SkyLight                            0x00007ff80ec30686 SLSGetNextEventRecordInternal + 284
# 16  SkyLight                            0x00007ff80ea4caec SLEventCreateNextEvent + 9
# 17  HIToolbox                           0x00007ff813c59156 _ZL38PullEventsFromWindowServerOnConnectionjhP17__CFMachPortBoost + 45
# 18  HIToolbox                           0x00007ff813c590fb _ZL14MessageHandlerP12__CFMachPortPvlS1_ + 48
# 19  CoreFoundation                      0x00007ff809de918c __CFMachPortPerform + 244
# 20  CoreFoundation                      0x00007ff809dbc3f8 __CFRUNLOOP_IS_CALLING_OUT_TO_A_SOURCE1_PERFORM_FUNCTION__ + 41
# 21  CoreFoundation                      0x00007ff809dbc337 __CFRunLoopDoSource1 + 536
# 22  CoreFoundation                      0x00007ff809dbafb6 __CFRunLoopRun + 2749
# 23  CoreFoundation                      0x00007ff809db9e7f CFRunLoopRunSpecific + 560
# 24  HIToolbox                           0x00007ff813c4c766 RunCurrentEventLoopInMode + 292
# 25  HIToolbox                           0x00007ff813c4c396 ReceiveNextEventCommon + 199
# 26  HIToolbox                           0x00007ff813c4c2b3 _BlockUntilNextEventMatchingListInModeWithFilter + 70
# 27  AppKit                              0x00007ff80ce452f3 _DPSNextEvent + 909
# 28  AppKit                              0x00007ff80ce44174 -[NSApplication(NSEvent) _nextEventMatchingEventMask:untilDate:inMode:dequeue:] + 1219
# 29  libopencv_highgui.4.5.2.dylib       0x000000010bec41b1 cvWaitKey + 353
# 30  libopencv_highgui.4.5.2.dylib       0x000000010bebfd12 _ZN2cv7waitKeyEi + 66
# 31  cv2.cpython-39-darwin.so            0x000000010c0473c6 _ZL19pyopencv_cv_waitKeyP7_objectS0_S0_ + 150
# 32  python3.9                           0x0000000100d36884 cfunction_call + 52
# 33  python3.9                           0x0000000100cdac48 _PyObject_MakeTpCall + 136
# 34  python3.9                           0x0000000100e0a2b7 call_function + 311
# 35  python3.9                           0x0000000100e07d5f _PyEval_EvalFrameDefault + 44175
# 36  python3.9                           0x0000000100dfbc6d _PyEval_EvalCode + 557
# 37  python3.9                           0x0000000100df63e2 builtin_exec + 370
# 38  python3.9                           0x0000000100d37353 cfunction_vectorcall_FASTCALL + 99
# 39  python3.9                           0x0000000100e0a22c call_function + 172
# 40  python3.9                           0x0000000100e07d95 _PyEval_EvalFrameDefault + 44229
# 41  python3.9                           0x0000000100cf4871 gen_send_ex + 177
# 42  python3.9                           0x0000000100e01e76 _PyEval_EvalFrameDefault + 19878
# 43  python3.9                           0x0000000100cf4871 gen_send_ex + 177
# 44  python3.9                           0x0000000100e01e76 _PyEval_EvalFrameDefault + 19878
# 45  python3.9                           0x0000000100cf4871 gen_send_ex + 177
# 46  python3.9                           0x0000000100ce9b15 method_vectorcall_O + 117
# 47  python3.9                           0x0000000100e0a22c call_function + 172
# 48  python3.9                           0x0000000100e07cb9 _PyEval_EvalFrameDefault + 44009
# 49  python3.9                           0x0000000100cdbe78 _PyFunction_Vectorcall + 248
# 50  python3.9                           0x0000000100e0a22c call_function + 172
# 51  python3.9                           0x0000000100e07d95 _PyEval_EvalFrameDefault + 44229
# 52  python3.9                           0x0000000100cdbe78 _PyFunction_Vectorcall + 248
# 53  python3.9                           0x0000000100e0a22c call_function + 172
# 54  python3.9                           0x0000000100e07cb9 _PyEval_EvalFrameDefault + 44009
# 55  python3.9                           0x0000000100dfbc6d _PyEval_EvalCode + 557
# 56  python3.9                           0x0000000100cdbf31 _PyFunction_Vectorcall + 433
# 57  python3.9                           0x0000000100cdf26e method_vectorcall + 158
# 58  python3.9                           0x0000000100cdb9d3 PyVectorcall_Call + 163
# 59  python3.9                           0x0000000100e07fa4 _PyEval_EvalFrameDefault + 44756
# 60  python3.9                           0x0000000100dfbc6d _PyEval_EvalCode + 557
# 61  python3.9                           0x0000000100cdbf31 _PyFunction_Vectorcall + 433
# 62  python3.9                           0x0000000100cdf26e method_vectorcall + 158
# 63  python3.9                           0x0000000100e0a22c call_function + 172
# 64  python3.9                           0x0000000100e07e52 _PyEval_EvalFrameDefault + 44418
# 65  python3.9                           0x0000000100cf4871 gen_send_ex + 177
# 66  python3.9                           0x0000000100e01e76 _PyEval_EvalFrameDefault + 19878
# 67  python3.9                           0x0000000100cf4871 gen_send_ex + 177
# 68  python3.9                           0x0000000100e01e76 _PyEval_EvalFrameDefault + 19878
# 69  python3.9                           0x0000000100cf4871 gen_send_ex + 177
# 70  python3.9                           0x0000000100e01e76 _PyEval_EvalFrameDefault + 19878
# 71  python3.9                           0x0000000100cf4871 gen_send_ex + 177
# 72  python3.9                           0x0000000100e01e76 _PyEval_EvalFrameDefault + 19878
# 73  python3.9                           0x0000000100cf4871 gen_send_ex + 177
# 74  _asyncio.cpython-39-darwin.so       0x000000010a4ff9ba task_step_impl + 442
# 75  _asyncio.cpython-39-darwin.so       0x000000010a4ff76e task_step + 62
# 76  _asyncio.cpython-39-darwin.so       0x000000010a4ff608 task_wakeup + 104
# 77  _asyncio.cpython-39-darwin.so       0x000000010a4ff4fd TaskWakeupMethWrapper_call + 109
# 78  python3.9                           0x0000000100cdac48 _PyObject_MakeTpCall + 136
# 79  python3.9                           0x0000000100e29d81 context_run + 81
# 80  python3.9                           0x0000000100d37241 cfunction_vectorcall_FASTCALL_KEYWORDS + 81
# 81  python3.9                           0x0000000100e07fa4 _PyEval_EvalFrameDefault + 44756
# 82  python3.9                           0x0000000100cdbe78 _PyFunction_Vectorcall + 248
# 83  python3.9                           0x0000000100e0a22c call_function + 172
# 84  python3.9                           0x0000000100e07cb9 _PyEval_EvalFrameDefault + 44009
# 85  python3.9                           0x0000000100cdbe78 _PyFunction_Vectorcall + 248
# 86  python3.9                           0x0000000100e0a22c call_function + 172
# 87  python3.9                           0x0000000100e07cb9 _PyEval_EvalFrameDefault + 44009
# 88  python3.9                           0x0000000100cdbe78 _PyFunction_Vectorcall + 248
# 89  python3.9                           0x0000000100e0a22c call_function + 172
# 90  python3.9                           0x0000000100e07cb9 _PyEval_EvalFrameDefault + 44009
# 91  python3.9                           0x0000000100cdbe78 _PyFunction_Vectorcall + 248
# 92  python3.9                           0x0000000100e0a22c call_function + 172
# 93  python3.9                           0x0000000100e07cb9 _PyEval_EvalFrameDefault + 44009
# 94  python3.9                           0x0000000100cdbe78 _PyFunction_Vectorcall + 248
# 95  python3.9                           0x0000000100e0a22c call_function + 172
# 96  python3.9                           0x0000000100e07cb9 _PyEval_EvalFrameDefault + 44009
# 97  python3.9                           0x0000000100dfbc6d _PyEval_EvalCode + 557
# 98  python3.9                           0x0000000100cdbf31 _PyFunction_Vectorcall + 433
# 99  python3.9                           0x0000000100cdf26e method_vectorcall + 158
# 100 python3.9                           0x0000000100e0a22c call_function + 172
# 101 python3.9                           0x0000000100e07d5f _PyEval_EvalFrameDefault + 44175
# 102 python3.9                           0x0000000100dfbc6d _PyEval_EvalCode + 557
# 103 python3.9                           0x0000000100df63e2 builtin_exec + 370
# 104 python3.9                           0x0000000100d37353 cfunction_vectorcall_FASTCALL + 99
# 105 python3.9                           0x0000000100e0a22c call_function + 172
# 106 python3.9                           0x0000000100e07d95 _PyEval_EvalFrameDefault + 44229
# 107 python3.9                           0x0000000100dfbc6d _PyEval_EvalCode + 557
# 108 python3.9                           0x0000000100cdbf31 _PyFunction_Vectorcall + 433
# 109 python3.9                           0x0000000100e0a22c call_function + 172
# 110 python3.9                           0x0000000100e07d95 _PyEval_EvalFrameDefault + 44229
# 111 python3.9                           0x0000000100dfbc6d _PyEval_EvalCode + 557
# 112 python3.9                           0x0000000100cdbf31 _PyFunction_Vectorcall + 433
# 113 python3.9                           0x0000000100e920d2 pymain_run_module + 258
# 114 python3.9                           0x0000000100e919ad pymain_run_python + 237
# 115 python3.9                           0x0000000100e91865 Py_RunMain + 37
# 116 python3.9                           0x0000000100e92f11 pymain_main + 49
# 117 python3.9                           0x0000000100c6ae98 main + 56
# 118 dyld                                0x0000000201203310 start + 2432
# 1   HIToolbox                           0x00007ff813c4c0c2 _ZN15MenuBarInstance22RemoveAutoShowObserverEv + 30
# 2   HIToolbox                           0x00007ff813cbff72 _ZN15MenuBarInstance15DisableAutoShowEv + 24
# 3   HIToolbox                           0x00007ff813cc0077 _ZN15MenuBarInstanceD2Ev + 113
# 4   HIToolbox                           0x00007ff813cbfebb _ZN15MenuBarInstance7ReleaseEv + 35
# 5   AppKit                              0x00007ff80d5bd9dd -[NSHIPresentationInstance discard] + 277
# 6   AppKit                              0x00007ff80da25702 -[_NSFullScreenSpace(PresentationInstance) discardPresentationInstance] + 36
# 7   AppKit                              0x00007ff80da25777 -[_NSFullScreenSpace(PresentationInstance) activateFullScreenPresentationOptions] + 86
# 8   AppKit                              0x00007ff80d83db41 -[_NSExitFullScreenTransitionController _doSucceededToExitFullScreen] + 38
# 9   AppKit                              0x00007ff80d83e6a3 __63-[_NSExitFullScreenTransitionController _performExitFullScreen]_block_invoke + 249
# 10  libxpc.dylib                        0x00007ff809a4f21f _xpc_connection_reply_callout + 36
# 11  libxpc.dylib                        0x00007ff809a4f1a7 _xpc_connection_call_reply_async + 69
# 12  libdispatch.dylib                   0x00007ff809b61aaa _dispatch_client_callout3 + 8
# 13  libdispatch.dylib                   0x00007ff809b7cc6f _dispatch_mach_msg_async_reply_invoke + 387
# 14  libdispatch.dylib                   0x00007ff809b6e6ee _dispatch_main_queue_drain + 749
# 15  libdispatch.dylib                   0x00007ff809b6e3f3 _dispatch_main_queue_callback_4CF + 31
# 16  CoreFoundation                      0x00007ff809dfa42d __CFRUNLOOP_IS_SERVICING_THE_MAIN_DISPATCH_QUEUE__ + 9
# 17  CoreFoundation                      0x00007ff809dbaebb __CFRunLoopRun + 2498
# 18  CoreFoundation                      0x00007ff809db9e7f CFRunLoopRunSpecific + 560
# 19  HIToolbox                           0x00007ff813c4c766 RunCurrentEventLoopInMode + 292
# 20  HIToolbox                           0x00007ff813c4c396 ReceiveNextEventCommon + 199
# 21  HIToolbox                           0x00007ff813c4c2b3 _BlockUntilNextEventMatchingListInModeWithFilter + 70
# 22  AppKit                              0x00007ff80ce452f3 _DPSNextEvent + 909
# 23  AppKit                              0x00007ff80ce44174 -[NSApplication(NSEvent) _nextEventMatchingEventMask:untilDate:inMode:dequeue:] + 1219
# 24  libopencv_highgui.4.5.2.dylib       0x000000010bec41b1 cvWaitKey + 353
# 25  libopencv_highgui.4.5.2.dylib       0x000000010bebfd12 _ZN2cv7waitKeyEi + 66
# 26  cv2.cpython-39-darwin.so            0x000000010c0473c6 _ZL19pyopencv_cv_waitKeyP7_objectS0_S0_ + 150
# 27  python3.9                           0x0000000100d36884 cfunction_call + 52
# 28  python3.9                           0x0000000100cdac48 _PyObject_MakeTpCall + 136
# 29  python3.9                           0x0000000100e0a2b7 call_function + 311
# 30  python3.9                           0x0000000100e07d5f _PyEval_EvalFrameDefault + 44175
# 31  python3.9                           0x0000000100dfbc6d _PyEval_EvalCode + 557
# 32  python3.9                           0x0000000100df63e2 builtin_exec + 370
# 33  python3.9                           0x0000000100d37353 cfunction_vectorcall_FASTCALL + 99
# 34  python3.9                           0x0000000100e0a22c call_function + 172
# 35  python3.9                           0x0000000100e07d95 _PyEval_EvalFrameDefault + 44229
# 36  python3.9                           0x0000000100cf4871 gen_send_ex + 177
# 37  python3.9                           0x0000000100e01e76 _PyEval_EvalFrameDefault + 19878
# 38  python3.9                           0x0000000100cf4871 gen_send_ex + 177
# 39  python3.9                           0x0000000100e01e76 _PyEval_EvalFrameDefault + 19878
# 40  python3.9                           0x0000000100cf4871 gen_send_ex + 177
# 41  python3.9                           0x0000000100ce9b15 method_vectorcall_O + 117
# 42  python3.9                           0x0000000100e0a22c call_function + 172
# 43  python3.9                           0x0000000100e07cb9 _PyEval_EvalFrameDefault + 44009
# 44  python3.9                           0x0000000100cdbe78 _PyFunction_Vectorcall + 248
# 45  python3.9                           0x0000000100e0a22c call_function + 172
# 46  python3.9                           0x0000000100e07d95 _PyEval_EvalFrameDefault + 44229
# 47  python3.9                           0x0000000100cdbe78 _PyFunction_Vectorcall + 248
# 48  python3.9                           0x0000000100e0a22c call_function + 172
# 49  python3.9                           0x0000000100e07cb9 _PyEval_EvalFrameDefault + 44009
# 50  python3.9                           0x0000000100dfbc6d _PyEval_EvalCode + 557
# 51  python3.9                           0x0000000100cdbf31 _PyFunction_Vectorcall + 433
# 52  python3.9                           0x0000000100cdf26e method_vectorcall + 158
# 53  python3.9                           0x0000000100cdb9d3 PyVectorcall_Call + 163
# 54  python3.9                           0x0000000100e07fa4 _PyEval_EvalFrameDefault + 44756
# 55  python3.9                           0x0000000100dfbc6d _PyEval_EvalCode + 557
# 56  python3.9                           0x0000000100cdbf31 _PyFunction_Vectorcall + 433
# 57  python3.9                           0x0000000100cdf26e method_vectorcall + 158
# 58  python3.9                           0x0000000100e0a22c call_function + 172
# 59  python3.9                           0x0000000100e07e52 _PyEval_EvalFrameDefault + 44418
# 60  python3.9                           0x0000000100cf4871 gen_send_ex + 177
# 61  python3.9                           0x0000000100e01e76 _PyEval_EvalFrameDefault + 19878
# 62  python3.9                           0x0000000100cf4871 gen_send_ex + 177
# 63  python3.9                           0x0000000100e01e76 _PyEval_EvalFrameDefault + 19878
# 64  python3.9                           0x0000000100cf4871 gen_send_ex + 177
# 65  python3.9                           0x0000000100e01e76 _PyEval_EvalFrameDefault + 19878
# 66  python3.9                           0x0000000100cf4871 gen_send_ex + 177
# 67  python3.9                           0x0000000100e01e76 _PyEval_EvalFrameDefault + 19878
# 68  python3.9                           0x0000000100cf4871 gen_send_ex + 177
# 69  _asyncio.cpython-39-darwin.so       0x000000010a4ff9ba task_step_impl + 442
# 70  _asyncio.cpython-39-darwin.so       0x000000010a4ff76e task_step + 62
# 71  _asyncio.cpython-39-darwin.so       0x000000010a4ff608 task_wakeup + 104
# 72  _asyncio.cpython-39-darwin.so       0x000000010a4ff4fd TaskWakeupMethWrapper_call + 109
# 73  python3.9                           0x0000000100cdac48 _PyObject_MakeTpCall + 136
# 74  python3.9                           0x0000000100e29d81 context_run + 81
# 75  python3.9                           0x0000000100d37241 cfunction_vectorcall_FASTCALL_KEYWORDS + 81
# 76  python3.9                           0x0000000100e07fa4 _PyEval_EvalFrameDefault + 44756
# 77  python3.9                           0x0000000100cdbe78 _PyFunction_Vectorcall + 248
# 78  python3.9                           0x0000000100e0a22c call_function + 172
# 79  python3.9                           0x0000000100e07cb9 _PyEval_EvalFrameDefault + 44009
# 80  python3.9                           0x0000000100cdbe78 _PyFunction_Vectorcall + 248
# 81  python3.9                           0x0000000100e0a22c call_function + 172
# 82  python3.9                           0x0000000100e07cb9 _PyEval_EvalFrameDefault + 44009
# 83  python3.9                           0x0000000100cdbe78 _PyFunction_Vectorcall + 248
# 84  python3.9                           0x0000000100e0a22c call_function + 172
# 85  python3.9                           0x0000000100e07cb9 _PyEval_EvalFrameDefault + 44009
# 86  python3.9                           0x0000000100cdbe78 _PyFunction_Vectorcall + 248
# 87  python3.9                           0x0000000100e0a22c call_function + 172
# 88  python3.9                           0x0000000100e07cb9 _PyEval_EvalFrameDefault + 44009
# 89  python3.9                           0x0000000100cdbe78 _PyFunction_Vectorcall + 248
# 90  python3.9                           0x0000000100e0a22c call_function + 172
# 91  python3.9                           0x0000000100e07cb9 _PyEval_EvalFrameDefault + 44009
# 92  python3.9                           0x0000000100dfbc6d _PyEval_EvalCode + 557
# 93  python3.9                           0x0000000100cdbf31 _PyFunction_Vectorcall + 433
# 94  python3.9                           0x0000000100cdf26e method_vectorcall + 158
# 95  python3.9                           0x0000000100e0a22c call_function + 172
# 96  python3.9                           0x0000000100e07d5f _PyEval_EvalFrameDefault + 44175
# 97  python3.9                           0x0000000100dfbc6d _PyEval_EvalCode + 557
# 98  python3.9                           0x0000000100df63e2 builtin_exec + 370
# 99  python3.9                           0x0000000100d37353 cfunction_vectorcall_FASTCALL + 99
# 100 python3.9                           0x0000000100e0a22c call_function + 172
# 101 python3.9                           0x0000000100e07d95 _PyEval_EvalFrameDefault + 44229
# 102 python3.9                           0x0000000100dfbc6d _PyEval_EvalCode + 557
# 103 python3.9                           0x0000000100cdbf31 _PyFunction_Vectorcall + 433
# 104 python3.9                           0x0000000100e0a22c call_function + 172
# 105 python3.9                           0x0000000100e07d95 _PyEval_EvalFrameDefault + 44229
# 106 python3.9                           0x0000000100dfbc6d _PyEval_EvalCode + 557
# 107 python3.9                           0x0000000100cdbf31 _PyFunction_Vectorcall + 433
# 108 python3.9                           0x0000000100e920d2 pymain_run_module + 258
# 109 python3.9                           0x0000000100e919ad pymain_run_python + 237
# 110 python3.9                           0x0000000100e91865 Py_RunMain + 37
# 111 python3.9                           0x0000000100e92f11 pymain_main + 49
# 112 python3.9                           0x0000000100c6ae98 main + 56
# 113 dyld                                0x0000000201203310 start + 2432
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/x4/p6z4ctc11fl9gpj156978f1w0000gn/T/ipykernel_17653/2396998107.py in <module>
#      11
#      12     cv2.imshow('camera', frame)
# ---> 13     if cv2.waitKey(1) == ord('q'): # 사용자가 q를 입력하면
#      14         break
#      15
#
# KeyboardInterrupt:
